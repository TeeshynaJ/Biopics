# %% [markdown]
# <a href="https://colab.research.google.com/github/TeeshynaJ/Biopics/blob/main/Biopics_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This project uses the Biopics dataset, which was downloaded as part of a Codility assessment. It shows my attempt at solving the assessment tasks and my approach to working with the dataset.

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

df = pd.read_csv('/content/biopics.csv', encoding='latin1')

# %%
print(df.head())
# Out:
#                  title country  year_release  box_office type_of_subject  \
# 0  10 Rillington Place      UK          1971         NaN        Criminal
# 1     12 Years a Slave   US/UK          2013  56700000.0           Other
# 2            127 Hours   US/UK          2010  18300000.0         Athlete
# 3                 1987  Canada          2014         NaN           Other
# 4             20 Dates      US          1998    537000.0           Other
#
#      lead_actor_actress
# 0  Richard Attenborough
# 1      Chiwetel Ejiofor
# 2          James Franco
# 3     Jean-Carl Boucher
# 4       Myles Berkowitz

# %%
#Number of nulls per column

# %%
df.isna().sum()
# Out:
# title                   0
# country                 0
# year_release            0
# box_office            324
# type_of_subject         0
# lead_actor_actress      7
# dtype: int64

# %%
#Finding out number of duplicate rows

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %%
#Retrieve the duplicated
df[df.duplicated(keep=False)] # keep = flag all duplicates (first and later as True)
# Out:
#                   title country  year_release  box_office type_of_subject  \
# 55         Bandit Queen      UK          1994    400000.0        Criminal
# 71         Bandit Queen      UK          1994    400000.0        Criminal
# 90               Breach      US          2007  33000000.0        Criminal
# 117              Breach      US          2007  33000000.0        Criminal
# 142          Compulsion      US          1959         NaN        Criminal
# 143          Compulsion      US          1959         NaN        Criminal
# 536  The Bang Bang Club  Canada          2010         NaN           Media
# 537  The Bang Bang Club  Canada          2010         NaN           Media
# 538  The Bang Bang Club  Canada          2010         NaN           Media
#
#                   lead_actor_actress
# 55                      Seema Biswas
# 71                      Seema Biswas
# 90                      Chris Cooper
# 117                     Chris Cooper
# 142  Dean Stockwell/Bradford Dillman
# ...

# %%
#Drop duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [title, country, year_release, box_office, type_of_subject, lead_actor_actress]
# Index: []

# %%
#Rename the column

# %%
df.rename(columns={"box_office" :"earnings"},inplace=True)

# %%
print(df.head())
# Out:
#                  title country  year_release    earnings type_of_subject  \
# 0  10 Rillington Place      UK          1971         NaN        Criminal
# 1     12 Years a Slave   US/UK          2013  56700000.0           Other
# 2            127 Hours   US/UK          2010  18300000.0         Athlete
# 3                 1987  Canada          2014         NaN           Other
# 4             20 Dates      US          1998    537000.0           Other
#
#      lead_actor_actress
# 0  Richard Attenborough
# 1      Chiwetel Ejiofor
# 2          James Franco
# 3     Jean-Carl Boucher
# 4       Myles Berkowitz

# %%
df.isna().sum()
# Out:
# title                   0
# country                 0
# year_release            0
# earnings              321
# type_of_subject         0
# lead_actor_actress      5
# dtype: int64

# %% [markdown]
# #Drop nulls in earning columns

# %%
df.dropna(subset='earnings',inplace=True)

# %%
df.isna().sum()
# Out:
# title                 0
# country               0
# year_release          0
# earnings              0
# type_of_subject       0
# lead_actor_actress    2
# dtype: int64

# %%
#keep only movies released inthe year 1990 or later

# %%
df[df['year_release']>=1990]
# Out:
#                     title country  year_release    earnings type_of_subject  \
# 1        12 Years a Slave   US/UK          2013  56700000.0           Other
# 2               127 Hours   US/UK          2010  18300000.0         Athlete
# 4                20 Dates      US          1998    537000.0           Other
# 5                      21      US          2008  81200000.0           Other
# 6    24 Hour Party People      UK          2002   1130000.0        Musician
# ..                    ...     ...           ...         ...             ...
# 743                  Wild      US          2014  37900000.0           Other
# 744             Wild Bill      US          1995   2170000.0      Historical
# 745                 Wilde      UK          1997   2160000.0          Author
# 750        Without Limits      US          1998    777000.0         Athlete
# 754            Wyatt Earp      US          1994  25100000.0           Other
#
#     lead_actor_actress
# 1     Chiwetel Ejiofor
# ...

# %%
#convert the type of subject and country to categorical

# %%
df.dtypes
# Out:
# title                  object
# country                object
# year_release            int64
# earnings              float64
# type_of_subject        object
# lead_actor_actress     object
# dtype: object

# %%
df[['type_of_subject', 'country']]=df[['type_of_subject', 'country']].astype('category')

# %%
df.dtypes
# Out:
# title                   object
# country               category
# year_release             int64
# earnings               float64
# type_of_subject       category
# lead_actor_actress      object
# dtype: object

# %%
#create a new variable called lead_actor_actress_known that is false if lead_actor_actreess is Nan and True otherwise

# %%
df=df.assign(lead_actor_actress_known= df['lead_actor_actress'].notna())

# %%
print(df)
# Out:
#                     title country  year_release    earnings type_of_subject  \
# 1        12 Years a Slave   US/UK          2013  56700000.0           Other
# 2               127 Hours   US/UK          2010  18300000.0         Athlete
# 4                20 Dates      US          1998    537000.0           Other
# 5                      21      US          2008  81200000.0           Other
# 6    24 Hour Party People      UK          2002   1130000.0        Musician
# ..                    ...     ...           ...         ...             ...
# 745                 Wilde      UK          1997   2160000.0          Author
# 746                Wilson      US          1944   2000000.0    World leader
# 748                 Wired      US          1989   1090000.0        Comedian
# 750        Without Limits      US          1998    777000.0         Athlete
# 754            Wyatt Earp      US          1994  25100000.0           Other
#
#     lead_actor_actress  lead_actor_actress_known
# ...

# %%
#update earnings such thet are expressed in millions of dollars instead of dollars

# %%
df['earnings']=df['earnings']/1_000_000

# %%
print(df)
# Out:
#                     title country  year_release  earnings type_of_subject  \
# 1        12 Years a Slave   US/UK          2013    56.700           Other
# 2               127 Hours   US/UK          2010    18.300         Athlete
# 4                20 Dates      US          1998     0.537           Other
# 5                      21      US          2008    81.200           Other
# 6    24 Hour Party People      UK          2002     1.130        Musician
# ..                    ...     ...           ...       ...             ...
# 745                 Wilde      UK          1997     2.160          Author
# 746                Wilson      US          1944     2.000    World leader
# 748                 Wired      US          1989     1.090        Comedian
# 750        Without Limits      US          1998     0.777         Athlete
# 754            Wyatt Earp      US          1994    25.100           Other
#
#     lead_actor_actress  lead_actor_actress_known
# ...

# %%
df['earnings'].head()
# Out:
# 1    56.700
# 2    18.300
# 4     0.537
# 5    81.200
# 6     1.130
# Name: earnings, dtype: float64

# %%
#Reorder the columns in the dataframe such that they are in the following order: title, year_release,earnings,country,type of subject,lead_actor actress , lead_Actor_actree known

# %%
df.columns
# Out:
# Index(['title', 'country', 'year_release', 'earnings', 'type_of_subject',
#        'lead_actor_actress', 'lead_actor_actress_known'],
#       dtype='object')

# %%
new_df=df[['title', 'year_release','earnings','country','type_of_subject','lead_actor_actress','lead_actor_actress_known']]

# %%
#sort the rows in descendibg order by earnings

# %%
new_df.sort_values(by='earnings',ascending=False, inplace=True)

# %%
new_df.head()
# Out:
#                    title  year_release  earnings    country type_of_subject  \
# 38       American Sniper          2014     350.0         US        Military
# 547       The Blind Side          2009     256.0         US         Athlete
# 334              Lincoln          2012     182.0         US    World leader
# 11      A Beautiful Mind          2001     171.0         US        Academic
# 124  Catch Me If You Can          2002     164.0  US/Canada        Criminal
#
#     lead_actor_actress  lead_actor_actress_known
# 38      Bradley Cooper                      True
# 547      Quinton Aaron                      True
# 334   Daniel Day-Lewis                      True
# 11       Russell Crowe                      True
# 124  Leonardo DiCaprio                      True
